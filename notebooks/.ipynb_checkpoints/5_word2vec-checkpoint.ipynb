# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %matplotlib inline

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
words
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against',
#  'early',
#  'working',
#  'class',
#  'radicals',
#  'including',
#  'the',
#  'diggers',
#  'of',
#  'the',
#  'english',
#  'revolution',
#  'and',
#  'the',
#  'sans',
#  'culottes',
#  'of',
#  'the',
#  'french',
#  'revolution',
#  'whilst',
#  'the',
#  'term',
#  'is',
#  'still',
#  'used',
#  'in',
#  'a',
#  'pejorative',
#  'way',
#  'to',
#  'describe',
#  'any',
#  'act',
#  'that',
#  'used',
#  'violent',
#  'means',
#  'to',
#  'destroy',
#  'the',
#  'organization',
#  'of',
#  'society',
#  'it',
#  'has',
#  'also',
#  'been',
#  'taken',
#  'up',
#  'as',
#  'a',
#  'positive',
#  'label',
#  'by',
#  'self',
#  'defined',
#  'anarchists',
#  'the',
#  'word',
#  'anarchism',
#  'is',
#  'derived',
#  'from',
#  'the',
#  'greek',
#  'without',
#  'archons',
#  'ruler',
#  'chief',
#  'king',
#  'anarchism',
#  'as',
#  'a',
#  'political',
#  'philosophy',
#  'is',
#  'the',
#  'belief',
#  'that',
#  'rulers',
#  'are',
#  'unnecessary',
#  'and',
#  'should',
#  'be',
#  'abolished',
#  'although',
#  'there',
#  'are',
#  'differing',
#  'interpretations',
#  'of',
#  'what',
#  'this',
#  'means',
#  'anarchism',
#  'also',
#  'refers',
#  'to',
#  'related',
#  'social',
#  'movements',
#  'that',
#  'advocate',
#  'the',
#  'elimination',
#  'of',
#  'authoritarian',
#  'institutions',
#  'particularly',
#  'the',
#  'state',
#  'the',
#  'word',
#  'anarchy',
#  'as',
#  'most',
#  'anarchists',
#  'use',
#  'it',
#  'does',
#  'not',
#  'imply',
#  'chaos',
#  'nihilism',
#  'or',
#  'anomie',
#  'but',
#  'rather',
#  'a',
#  'harmonious',
#  'anti',
#  'authoritarian',
#  'society',
#  'in',
#  'place',
#  'of',
#  'what',
#  'are',
#  'regarded',
#  'as',
#  'authoritarian',
#  'political',
#  'structures',
#  'and',
#  'coercive',
#  'economic',
#  'institutions',
#  'anarchists',
#  'advocate',
#  'social',
#  'relations',
#  'based',
#  'upon',
#  'voluntary',
#  'association',
#  'of',
#  'autonomous',
#  'individuals',
#  'mutual',
#  'aid',
#  'and',
#  'self',
#  'governance',
#  'while',
#  'anarchism',
#  'is',
#  'most',
#  'easily',
#  'defined',
#  'by',
#  'what',
#  'it',
#  'is',
#  'against',
#  'anarchists',
#  'also',
#  'offer',
#  'positive',
#  'visions',
#  'of',
#  'what',
#  'they',
#  'believe',
#  'to',
#  'be',
#  'a',
#  'truly',
#  'free',
#  'society',
#  'however',
#  'ideas',
#  'about',
#  'how',
#  'an',
#  'anarchist',
#  'society',
#  'might',
#  'work',
#  'vary',
#  'considerably',
#  'especially',
#  'with',
#  'respect',
#  'to',
#  'economics',
#  'there',
#  'is',
#  'also',
#  'disagreement',
#  'about',
#  'how',
#  'a',
#  'free',
#  'society',
#  'might',
#  'be',
#  'brought',
#  'about',
#  'origins',
#  'and',
#  'predecessors',
#  'kropotkin',
#  'and',
#  'others',
#  'argue',
#  'that',
#  'before',
#  'recorded',
#  'history',
#  'human',
#  'society',
#  'was',
#  'organized',
#  'on',
#  'anarchist',
#  'principles',
#  'most',
#  'anthropologists',
#  'follow',
#  'kropotkin',
#  'and',
#  'engels',
#  'in',
#  'believing',
#  'that',
#  'hunter',
#  'gatherer',
#  'bands',
#  'were',
#  'egalitarian',
#  'and',
#  'lacked',
#  'division',
#  'of',
#  'labour',
#  'accumulated',
#  'wealth',
#  'or',
#  'decreed',
#  'law',
#  'and',
#  'had',
#  'equal',
#  'access',
#  'to',
#  'resources',
#  'william',
#  'godwin',
#  'anarchists',
#  'including',
#  'the',
#  'the',
#  'anarchy',
#  'organisation',
#  'and',
#  'rothbard',
#  'find',
#  'anarchist',
#  'attitudes',
#  'in',
#  'taoism',
#  'from',
#  'ancient',
#  'china',
#  'kropotkin',
#  'found',
#  'similar',
#  'ideas',
#  'in',
#  'stoic',
#  'zeno',
#  'of',
#  'citium',
#  'according',
#  'to',
#  'kropotkin',
#  'zeno',
#  'repudiated',
#  'the',
#  'omnipotence',
#  'of',
#  'the',
#  'state',
#  'its',
#  'intervention',
#  'and',
#  'regimentation',
#  'and',
#  'proclaimed',
#  'the',
#  'sovereignty',
#  'of',
#  'the',
#  'moral',
#  'law',
#  'of',
#  'the',
#  'individual',
#  'the',
#  'anabaptists',
#  'of',
#  'one',
#  'six',
#  'th',
#  'century',
#  'europe',
#  'are',
#  'sometimes',
#  'considered',
#  'to',
#  'be',
#  'religious',
#  'forerunners',
#  'of',
#  'modern',
#  'anarchism',
#  'bertrand',
#  'russell',
#  'in',
#  'his',
#  'history',
#  'of',
#  'western',
#  'philosophy',
#  'writes',
#  'that',
#  'the',
#  'anabaptists',
#  'repudiated',
#  'all',
#  'law',
#  'since',
#  'they',
#  'held',
#  'that',
#  'the',
#  'good',
#  'man',
#  'will',
#  'be',
#  'guided',
#  'at',
#  'every',
#  'moment',
#  'by',
#  'the',
#  'holy',
#  'spirit',
#  'from',
#  'this',
#  'premise',
#  'they',
#  'arrive',
#  'at',
#  'communism',
#  'the',
#  'diggers',
#  'or',
#  'true',
#  'levellers',
#  'were',
#  'an',
#  'early',
#  'communistic',
#  'movement',
#  'during',
#  'the',
#  'time',
#  'of',
#  'the',
#  'english',
#  'civil',
#  'war',
#  'and',
#  'are',
#  'considered',
#  'by',
#  'some',
#  'as',
#  'forerunners',
#  'of',
#  'modern',
#  'anarchism',
#  'in',
#  'the',
#  'modern',
#  'era',
#  'the',
#  'first',
#  'to',
#  'use',
#  'the',
#  'term',
#  'to',
#  'mean',
#  'something',
#  'other',
#  'than',
#  'chaos',
#  'was',
#  'louis',
#  'armand',
#  'baron',
#  'de',
#  'lahontan',
#  'in',
#  'his',
#  'nouveaux',
#  'voyages',
#  'dans',
#  'l',
#  'am',
#  'rique',
#  'septentrionale',
#  'one',
#  'seven',
#  'zero',
#  'three',
#  'where',
#  'he',
#  'described',
#  'the',
#  'indigenous',
#  'american',
#  'society',
#  'which',
#  'had',
#  'no',
#  'state',
#  'laws',
#  'prisons',
#  'priests',
#  'or',
#  'private',
#  'property',
#  'as',
#  'being',
#  'in',
#  'anarchy',
#  'russell',
#  'means',
#  'a',
#  'libertarian',
#  'and',
#  'leader',
#  'in',
#  'the',
#  'american',
#  'indian',
#  'movement',
#  'has',
#  'repeatedly',
#  'stated',
#  'that',
#  'he',
#  'is',
#  'an',
#  'anarchist',
#  'and',
#  'so',
#  'are',
#  'all',
#  'his',
#  'ancestors',
#  'in',
#  'one',
#  'seven',
#  'nine',
#  'three',
#  'in',
#  'the',
#  'thick',
#  'of',
#  'the',
#  'french',
#  'revolution',
#  'william',
#  'godwin',
#  'published',
#  'an',
#  'enquiry',
#  'concerning',
#  'political',
#  'justice',
#  'although',
#  'godwin',
#  'did',
#  'not',
#  'use',
#  'the',
#  'word',
#  'anarchism',
#  'many',
#  'later',
#  'anarchists',
#  'have',
#  'regarded',
#  'this',
#  'book',
#  'as',
#  'the',
#  'first',
#  'major',
#  'anarchist',
#  'text',
#  'and',
#  'godwin',
#  'as',
#  'the',
#  'founder',
#  'of',
#  'philosophical',
#  'anarchism',
#  'but',
#  'at',
#  'this',
#  'point',
#  'no',
#  'anarchist',
#  'movement',
#  'yet',
#  'existed',
#  'and',
#  'the',
#  'term',
#  'anarchiste',
#  'was',
#  'known',
#  'mainly',
#  'as',
#  'an',
#  'insult',
#  'hurled',
#  'by',
#  'the',
#  'bourgeois',
#  'girondins',
#  'at',
#  'more',
#  'radical',
#  'elements',
#  'in',
#  'the',
#  'french',
#  'revolution',
#  'the',
#  'first',
#  'self',
#  'labelled',
#  'anarchist',
#  'pierre',
#  'joseph',
#  'proudhon',
#  'it',
#  'is',
#  'commonly',
#  'held',
#  'that',
#  'it',
#  'wasn',
#  't',
#  'until',
#  'pierre',
#  'joseph',
#  'proudhon',
#  'published',
#  'what',
#  'is',
#  'property',
#  'in',
#  'one',
#  'eight',
#  'four',
#  'zero',
#  'that',
#  'the',
#  'term',
#  'anarchist',
#  'was',
#  'adopted',
#  'as',
#  'a',
#  'self',
#  'description',
#  'it',
#  'is',
#  'for',
#  'this',
#  'reason',
#  'that',
#  'some',
#  'claim',
#  'proudhon',
#  'as',
#  'the',
#  'founder',
#  'of',
#  'modern',
#  'anarchist',
#  'theory',
#  'in',
#  'what',
#  'is',
#  'property',
#  'proudhon',
#  'answers',
#  'with',
#  'the',
#  'famous',
#  'accusation',
#  'property',
#  'is',
#  'theft',
#  'in',
#  'this',
#  'work',
#  'he',
#  'opposed',
#  'the',
#  'institution',
#  'of',
#  'decreed',
#  'property',
#  'propri',
#  't',
#  'where',
#  'owners',
#  'have',
#  'complete',
#  'rights',
#  'to',
#  'use',
#  'and',
#  'abuse',
#  'their',
#  'property',
#  'as',
#  'they',
#  'wish',
#  'such',
#  'as',
#  'exploiting',
#  'workers',
#  'for',
#  'profit',
#  'in',
#  'its',
#  'place',
#  'proudhon',
#  'supported',
#  'what',
#  'he',
#  'called',
#  'possession',
#  'individuals',
#  'can',
#  'have',
#  'limited',
#  'rights',
#  'to',
#  'use',
#  'resources',
#  'capital',
#  'and',
#  'goods',
#  'in',
#  'accordance',
#  'with',
#  'principles',
#  'of',
#  'equality',
#  'and',
#  'justice',
#  'proudhon',
#  's',
#  'vision',
#  'of',
#  'anarchy',
#  'which',
#  'he',
#  'called',
#  'mutualism',
#  'mutuellisme',
#  'involved',
#  'an',
#  'exchange',
#  'economy',
#  'where',
#  'individuals',
#  'and',
#  'groups',
#  'could',
#  'trade',
#  'the',
#  'products',
#  'of',
#  'their',
#  'labor',
#  'using',
#  'labor',
#  'notes',
#  'which',
#  'represented',
#  'the',
#  'amount',
#  'of',
#  'working',
#  'time',
#  'involved',
#  'in',
#  'production',
#  'this',
#  'would',
#  'ensure',
#  'that',
#  'no',
#  'one',
#  'would',
#  'profit',
#  'from',
#  'the',
#  'labor',
#  'of',
#  'others',
#  'workers',
#  'could',
#  'freely',
#  'join',
#  'together',
#  'in',
#  'co',
#  'operative',
#  'workshops',
#  'an',
#  'interest',
#  'free',
#  'bank',
#  'would',
#  'be',
#  'set',
#  'up',
#  'to',
#  'provide',
#  'everyone',
#  'with',
#  'access',
#  'to',
#  'the',
#  'means',
#  'of',
#  'production',
#  'proudhon',
#  's',
#  'ideas',
#  'were',
#  'influential',
#  'within',
#  'french',
#  'working',
#  'class',
#  'movements',
#  'and',
#  'his',
#  'followers',
#  'were',
#  'active',
#  'in',
#  'the',
#  'revolution',
#  'of',
#  'one',
#  'eight',
#  'four',
#  'eight',
#  'in',
#  'france',
#  'proudhon',
#  's',
#  'philosophy',
#  'of',
#  'property',
#  'is',
#  'complex',
#  'it',
#  'was',
#  'developed',
#  'in',
#  'a',
#  'number',
#  'of',
#  'works',
#  'over',
#  'his',
#  'lifetime',
#  'and',
#  'there',
#  'are',
#  'differing',
#  'interpretations',
#  'of',
#  'some',
#  'of',
#  'his',
#  'ideas',
#  'for',
#  'more',
#  'detailed',
#  'discussion',
#  'see',
#  'here',
#  'max',
#  'stirner',
#  's',
#  'egoism',
#  'in',
#  'his',
#  'the',
#  'ego',
#  'and',
#  'its',
#  'own',
#  'stirner',
#  'argued',
#  'that',
#  'most',
#  'commonly',
#  'accepted',
#  'social',
#  'institutions',
#  'including',
#  'the',
#  'notion',
#  'of',
#  'state',
#  'property',
#  'as',
#  'a',
#  'right',
#  'natural',
#  'rights',
#  'in',
#  'general',
#  'and',
#  'the',
#  'very',
#  'notion',
#  'of',
#  'society',
#  'were',
#  'mere',
#  'illusions',
#  'or',
#  'ghosts',
#  'in',
#  'the',
#  'mind',
#  'saying',
#  'of',
#  'society',
#  'that',
#  'the',
#  'individuals',
#  'are',
#  'its',
#  'reality',
#  'he',
#  'advocated',
#  'egoism',
#  'and',
#  'a',
#  'form',
#  'of',
#  'amoralism',
#  'in',
#  'which',
#  'individuals',
#  'would',
#  'unite',
#  'in',
#  'associations',
#  'of',
#  'egoists',
#  'only',
#  'when',
#  'it',
#  'was',
#  'in',
#  'their',
#  'self',
#  'interest',
#  'to',
#  'do',
#  'so',
#  'for',
#  'him',
#  'property',
#  'simply',
#  'comes',
#  'about',
#  'through',
#  'might',
#  'whoever',
#  'knows',
#  'how',
#  'to',
#  'take',
#  'to',
#  'defend',
#  'the',
#  'thing',
#  'to',
#  'him',
#  'belongs',
#  'property',
#  'and',
#  'what',
#  'i',
#  'have',
#  'in',
#  'my',
#  'power',
#  'that',
#  'is',
#  'my',
#  'own',
#  'so',
#  'long',
#  'as',
#  'i',
#  'assert',
#  'myself',
#  'as',
#  'holder',
#  'i',
#  'am',
#  'the',
#  'proprietor',
#  'of',
#  'the',
#  'thing',
#  'stirner',
#  'never',
#  'called',
#  'himself',
#  'an',
#  'anarchist',
#  'he',
#  'accepted',
#  'only',
#  'the',
#  'label',
#  'egoist',
#  'nevertheless',
#  'his',
#  'ideas',
#  'were',
#  'influential',
#  'on',
#  'many',
#  'individualistically',
#  'inclined',
#  'anarchists',
#  'although',
#  'interpretations',
#  'of',
#  'his',
#  'thought',
#  'are',
#  'diverse',
#  ...]

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    # Reduce words to 50000 most common ones
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1)) 
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
data
# Out:
# [5234,
#  3081,
#  12,
#  6,
#  195,
#  2,
#  3134,
#  46,
#  59,
#  156,
#  128,
#  742,
#  477,
#  10572,
#  134,
#  1,
#  27350,
#  2,
#  1,
#  103,
#  855,
#  3,
#  1,
#  15068,
#  0,
#  2,
#  1,
#  151,
#  855,
#  3581,
#  1,
#  195,
#  11,
#  191,
#  59,
#  5,
#  6,
#  10713,
#  215,
#  7,
#  1325,
#  105,
#  455,
#  20,
#  59,
#  2732,
#  363,
#  7,
#  3673,
#  1,
#  709,
#  2,
#  372,
#  27,
#  41,
#  37,
#  54,
#  540,
#  98,
#  12,
#  6,
#  1424,
#  2758,
#  19,
#  568,
#  687,
#  7089,
#  1,
#  248,
#  5234,
#  11,
#  1053,
#  28,
#  1,
#  321,
#  249,
#  44612,
#  2878,
#  793,
#  187,
#  5234,
#  12,
#  6,
#  201,
#  603,
#  11,
#  1,
#  1135,
#  20,
#  2622,
#  26,
#  8984,
#  3,
#  280,
#  32,
#  4148,
#  142,
#  60,
#  26,
#  6438,
#  4187,
#  2,
#  154,
#  33,
#  363,
#  5234,
#  37,
#  1138,
#  7,
#  448,
#  345,
#  1819,
#  20,
#  4861,
#  1,
#  6754,
#  2,
#  7574,
#  1775,
#  567,
#  1,
#  94,
#  1,
#  248,
#  11065,
#  12,
#  52,
#  7089,
#  90,
#  27,
#  271,
#  38,
#  5949,
#  4862,
#  20300,
#  29,
#  0,
#  42,
#  318,
#  6,
#  25637,
#  528,
#  7574,
#  372,
#  5,
#  259,
#  2,
#  154,
#  26,
#  1207,
#  12,
#  7574,
#  201,
#  1577,
#  3,
#  15201,
#  333,
#  1775,
#  7089,
#  4861,
#  345,
#  765,
#  161,
#  407,
#  5691,
#  756,
#  2,
#  4106,
#  1132,
#  4332,
#  1537,
#  3,
#  568,
#  8118,
#  99,
#  5234,
#  11,
#  52,
#  1408,
#  687,
#  19,
#  154,
#  27,
#  11,
#  156,
#  7089,
#  37,
#  2034,
#  1424,
#  8175,
#  2,
#  154,
#  47,
#  694,
#  7,
#  32,
#  6,
#  4149,
#  247,
#  372,
#  77,
#  949,
#  79,
#  311,
#  31,
#  4779,
#  372,
#  508,
#  140,
#  2313,
#  3554,
#  365,
#  24,
#  1822,
#  7,
#  1903,
#  60,
#  11,
#  37,
#  8400,
#  79,
#  311,
#  6,
#  247,
#  372,
#  508,
#  32,
#  754,
#  79,
#  1733,
#  3,
#  8041,
#  24173,
#  3,
#  276,
#  1694,
#  20,
#  152,
#  1033,
#  96,
#  225,
#  372,
#  18,
#  1814,
#  25,
#  4779,
#  1557,
#  52,
#  8119,
#  1466,
#  24173,
#  3,
#  12744,
#  5,
#  6131,
#  20,
#  4188,
#  21149,
#  2428,
#  40,
#  16456,
#  3,
#  7240,
#  862,
#  2,
#  1194,
#  10208,
#  2515,
#  29,
#  15069,
#  188,
#  3,
#  49,
#  1124,
#  913,
#  7,
#  1050,
#  468,
#  12298,
#  7089,
#  134,
#  1,
#  1,
#  11065,
#  3056,
#  3,
#  12061,
#  735,
#  4779,
#  6599,
#  5,
#  14623,
#  28,
#  451,
#  486,
#  24173,
#  199,
#  296,
#  949,
#  5,
#  20028,
#  20301,
#  2,
#  0,
#  301,
#  7,
#  24173,
#  20301,
#  16457,
#  1,
#  30107,
#  2,
#  1,
#  94,
#  45,
#  3833,
#  3,
#  0,
#  3,
#  3808,
#  1,
#  3413,
#  2,
#  1,
#  1777,
#  188,
#  2,
#  1,
#  626,
#  1,
#  13142,
#  2,
#  4,
#  22,
#  91,
#  123,
#  285,
#  26,
#  244,
#  233,
#  7,
#  32,
#  437,
#  26185,
#  2,
#  174,
#  5234,
#  7700,
#  2535,
#  5,
#  30,
#  96,
#  2,
#  290,
#  603,
#  4309,
#  20,
#  1,
#  13142,
#  16457,
#  50,
#  188,
#  118,
#  47,
#  360,
#  20,
#  1,
#  385,
#  243,
#  97,
#  32,
#  5235,
#  35,
#  332,
#  2724,
#  19,
#  1,
#  839,
#  1377,
#  28,
#  33,
#  8762,
#  47,
#  6471,
#  35,
#  3244,
#  1,
#  27350,
#  29,
#  552,
#  42433,
#  40,
#  31,
#  128,
#  0,
#  436,
#  85,
#  1,
#  65,
#  2,
#  1,
#  103,
#  463,
#  84,
#  3,
#  26,
#  233,
#  19,
#  48,
#  12,
#  26185,
#  2,
#  174,
#  5234,
#  5,
#  1,
#  174,
#  840,
#  1,
#  46,
#  7,
#  90,
#  1,
#  195,
#  7,
#  1015,
#  1044,
#  43,
#  70,
#  4862,
#  18,
#  937,
#  14921,
#  4572,
#  165,
#  0,
#  5,
#  30,
#  40562,
#  11816,
#  22893,
#  260,
#  1226,
#  0,
#  0,
#  4,
#  23,
#  8,
#  17,
#  100,
#  36,
#  629,
#  1,
#  2663,
#  64,
#  372,
#  34,
#  49,
#  76,
#  94,
#  688,
#  14778,
#  4045,
#  29,
#  818,
#  918,
#  12,
#  102,
#  5,
#  11065,
#  2535,
#  363,
#  6,
#  6055,
#  3,
#  663,
#  5,
#  1,
#  64,
#  702,
#  436,
#  41,
#  4219,
#  1290,
#  20,
#  36,
#  11,
#  31,
#  4779,
#  3,
#  95,
#  26,
#  50,
#  30,
#  5213,
#  5,
#  4,
#  23,
#  9,
#  17,
#  5,
#  1,
#  5349,
#  2,
#  1,
#  151,
#  855,
#  468,
#  12298,
#  335,
#  31,
#  17195,
#  2435,
#  201,
#  1294,
#  142,
#  12298,
#  216,
#  38,
#  90,
#  1,
#  248,
#  5234,
#  56,
#  117,
#  7089,
#  39,
#  1207,
#  33,
#  198,
#  12,
#  1,
#  46,
#  182,
#  4779,
#  530,
#  3,
#  12298,
#  12,
#  1,
#  1835,
#  2,
#  1913,
#  5234,
#  42,
#  35,
#  33,
#  229,
#  76,
#  4779,
#  436,
#  734,
#  2400,
#  3,
#  1,
#  195,
#  0,
#  18,
#  87,
#  1074,
#  12,
#  31,
#  14023,
#  30108,
#  19,
#  1,
#  12062,
#  0,
#  35,
#  51,
#  2420,
#  617,
#  5,
#  1,
#  151,
#  855,
#  1,
#  46,
#  568,
#  8717,
#  4779,
#  2936,
#  1034,
#  14498,
#  27,
#  11,
#  637,
#  360,
#  20,
#  27,
#  5386,
#  155,
#  192,
#  2936,
#  1034,
#  14498,
#  335,
#  154,
#  11,
#  918,
#  5,
#  4,
#  13,
#  21,
#  8,
#  20,
#  1,
#  195,
#  4779,
#  18,
#  990,
#  12,
#  6,
#  568,
#  1607,
#  27,
#  11,
#  14,
#  33,
#  891,
#  20,
#  48,
#  849,
#  14498,
#  12,
#  1,
#  1835,
#  2,
#  174,
#  4779,
#  209,
#  5,
#  154,
#  11,
#  918,
#  14498,
#  5464,
#  24,
#  1,
#  420,
#  12954,
#  918,
#  11,
#  6879,
#  5,
#  33,
#  140,
#  36,
#  1347,
#  1,
#  2879,
#  2,
#  15069,
#  918,
#  0,
#  155,
#  100,
#  3466,
#  39,
#  653,
#  446,
#  7,
#  90,
#  3,
#  3134,
#  44,
#  918,
#  12,
#  47,
#  3592,
#  55,
#  12,
#  15348,
#  1556,
#  14,
#  2966,
#  5,
#  45,
#  259,
#  14498,
#  1165,
#  154,
#  36,
#  89,
#  3222,
#  1132,
#  53,
#  39,
#  752,
#  446,
#  7,
#  90,
#  1050,
#  523,
#  3,
#  1792,
#  5,
#  5806,
#  24,
#  1557,
#  2,
#  5129,
#  3,
#  1294,
#  14498,
#  15,
#  2655,
#  2,
#  11065,
#  34,
#  36,
#  89,
#  29373,
#  0,
#  967,
#  31,
#  1335,
#  519,
#  100,
#  1132,
#  3,
#  309,
#  160,
#  513,
#  1,
#  806,
#  2,
#  44,
#  1259,
#  219,
#  1259,
#  1038,
#  34,
#  1392,
#  1,
#  909,
#  2,
#  742,
#  65,
#  967,
#  5,
#  443,
#  33,
#  74,
#  2914,
#  20,
#  76,
#  4,
#  74,
#  2966,
#  28,
#  1,
#  1259,
#  2,
#  276,
#  1556,
#  160,
#  4320,
#  2519,
#  499,
#  5,
#  728,
#  10639,
#  18742,
#  31,
#  763,
#  247,
#  987,
#  74,
#  32,
#  178,
#  98,
#  7,
#  741,
#  3273,
#  24,
#  913,
#  7,
#  1,
#  363,
#  2,
#  443,
#  14498,
#  15,
#  949,
#  40,
#  2026,
#  223,
#  151,
#  742,
#  477,
#  1819,
#  3,
#  30,
#  2986,
#  40,
#  1022,
#  5,
#  1,
#  855,
#  2,
#  4,
#  13,
#  21,
#  13,
#  5,
#  303,
#  14498,
#  15,
#  603,
#  2,
#  918,
#  11,
#  648,
#  27,
#  18,
#  348,
#  5,
#  6,
#  113,
#  2,
#  312,
#  80,
#  30,
#  3568,
#  3,
#  60,
#  26,
#  6438,
#  4187,
#  2,
#  48,
#  2,
#  30,
#  949,
#  14,
#  51,
#  2159,
#  1590,
#  68,
#  622,
#  2750,
#  26186,
#  15,
#  15644,
#  5,
#  30,
#  1,
#  10465,
#  3,
#  45,
#  200,
#  26186,
#  1461,
#  20,
#  52,
#  637,
#  1046,
#  345,
#  1775,
#  134,
#  1,
#  2582,
#  2,
#  94,
#  918,
#  12,
#  6,
#  245,
#  390,
#  446,
#  5,
#  153,
#  3,
#  1,
#  148,
#  2582,
#  2,
#  372,
#  40,
#  4580,
#  20848,
#  29,
#  9217,
#  5,
#  1,
#  941,
#  1975,
#  2,
#  372,
#  20,
#  1,
#  1132,
#  26,
#  45,
#  1729,
#  36,
#  5214,
#  15644,
#  3,
#  6,
#  144,
#  2,
#  0,
#  5,
#  34,
#  1132,
#  74,
#  9712,
#  5,
#  5826,
#  2,
#  0,
#  67,
#  62,
#  27,
#  18,
#  5,
#  44,
#  568,
#  763,
#  7,
#  176,
#  95,
#  14,
#  119,
#  918,
#  685,
#  1146,
#  79,
#  124,
#  508,
#  13043,
#  5568,
#  311,
#  7,
#  370,
#  7,
#  4107,
#  1,
#  1798,
#  7,
#  119,
#  5465,
#  918,
#  3,
#  154,
#  72,
#  39,
#  5,
#  609,
#  184,
#  20,
#  11,
#  609,
#  200,
#  95,
#  185,
#  12,
#  72,
#  6188,
#  9034,
#  12,
#  7184,
#  72,
#  1226,
#  1,
#  33801,
#  2,
#  1,
#  1798,
#  26186,
#  364,
#  89,
#  392,
#  31,
#  4779,
#  36,
#  1046,
#  67,
#  1,
#  2758,
#  42434,
#  2069,
#  30,
#  949,
#  40,
#  2026,
#  25,
#  56,
#  0,
#  9930,
#  7089,
#  142,
#  4187,
#  2,
#  30,
#  502,
#  26,
#  3236,
#  ...]

# %%
count
# Out:
# [['UNK', 418391],
#  ('the', 1061396),
#  ('of', 593677),
#  ('and', 416629),
#  ('one', 411764),
#  ('in', 372201),
#  ('a', 325873),
#  ('to', 316376),
#  ('zero', 264975),
#  ('nine', 250430),
#  ('two', 192644),
#  ('is', 183153),
#  ('as', 131815),
#  ('eight', 125285),
#  ('for', 118445),
#  ('s', 116710),
#  ('five', 115789),
#  ('three', 114775),
#  ('was', 112807),
#  ('by', 111831),
#  ('that', 109510),
#  ('four', 108182),
#  ('six', 102145),
#  ('seven', 99683),
#  ('with', 95603),
#  ('on', 91250),
#  ('are', 76527),
#  ('it', 73334),
#  ('from', 72871),
#  ('or', 68945),
#  ('his', 62603),
#  ('an', 61925),
#  ('be', 61281),
#  ('this', 58832),
#  ('which', 54788),
#  ('at', 54576),
#  ('he', 53573),
#  ('also', 44358),
#  ('not', 44033),
#  ('have', 39712),
#  ('were', 39086),
#  ('has', 37866),
#  ('but', 35358),
#  ('other', 32433),
#  ('their', 31523),
#  ('its', 29567),
#  ('first', 28810),
#  ('they', 28553),
#  ('some', 28161),
#  ('had', 28100),
#  ('all', 26229),
#  ('more', 26223),
#  ('most', 25563),
#  ('can', 25519),
#  ('been', 25383),
#  ('such', 24413),
#  ('many', 24096),
#  ('who', 23997),
#  ('new', 23770),
#  ('used', 22737),
#  ('there', 22707),
#  ('after', 21125),
#  ('when', 20623),
#  ('into', 20484),
#  ('american', 20477),
#  ('time', 20412),
#  ('these', 19864),
#  ('only', 19463),
#  ('see', 19206),
#  ('may', 19115),
#  ('than', 18807),
#  ('world', 17949),
#  ('i', 17581),
#  ('b', 17516),
#  ('would', 17377),
#  ('d', 17236),
#  ('no', 16155),
#  ('however', 15861),
#  ('between', 15737),
#  ('about', 15574),
#  ('over', 15122),
#  ('years', 14935),
#  ('states', 14916),
#  ('people', 14696),
#  ('war', 14629),
#  ('during', 14578),
#  ('united', 14494),
#  ('known', 14437),
#  ('if', 14420),
#  ('called', 14151),
#  ('use', 14011),
#  ('th', 13380),
#  ('system', 13296),
#  ('often', 12987),
#  ('state', 12904),
#  ('so', 12722),
#  ('history', 12623),
#  ('will', 12560),
#  ('up', 12445),
#  ('while', 12363),
#  ('where', 12347),
#  ('city', 12275),
#  ('being', 11931),
#  ('english', 11868),
#  ('then', 11847),
#  ('any', 11803),
#  ('both', 11755),
#  ('under', 11753),
#  ('out', 11721),
#  ('made', 11701),
#  ('well', 11537),
#  ('her', 11536),
#  ('e', 11426),
#  ('number', 11399),
#  ('government', 11323),
#  ('them', 11285),
#  ('m', 10976),
#  ('later', 10971),
#  ('since', 10691),
#  ('him', 10629),
#  ('part', 10627),
#  ('name', 10572),
#  ('c', 10561),
#  ('century', 10550),
#  ('through', 10371),
#  ('because', 10332),
#  ('x', 10307),
#  ('university', 10195),
#  ('early', 10172),
#  ('life', 10096),
#  ('british', 10056),
#  ('year', 9858),
#  ('like', 9854),
#  ('same', 9774),
#  ('including', 9633),
#  ('became', 9591),
#  ('example', 9539),
#  ('day', 9534),
#  ('each', 9500),
#  ('even', 9412),
#  ('work', 9388),
#  ('language', 9375),
#  ('although', 9286),
#  ('several', 9168),
#  ('form', 9133),
#  ('john', 8956),
#  ('u', 8928),
#  ('national', 8904),
#  ('very', 8861),
#  ('much', 8822),
#  ('g', 8773),
#  ('french', 8736),
#  ('before', 8700),
#  ('general', 8659),
#  ('what', 8581),
#  ('t', 8491),
#  ('against', 8432),
#  ('n', 8372),
#  ('high', 8337),
#  ('links', 8312),
#  ('could', 8304),
#  ('based', 8244),
#  ('those', 8209),
#  ('now', 8206),
#  ('second', 8110),
#  ('de', 8002),
#  ('music', 7987),
#  ('another', 7933),
#  ('large', 7898),
#  ('she', 7896),
#  ('f', 7878),
#  ('external', 7862),
#  ('german', 7858),
#  ('different', 7797),
#  ('modern', 7790),
#  ('great', 7770),
#  ('do', 7763),
#  ('common', 7698),
#  ('set', 7682),
#  ('list', 7672),
#  ('south', 7628),
#  ('series', 7611),
#  ('major', 7585),
#  ('game', 7553),
#  ('power', 7522),
#  ('long', 7488),
#  ('country', 7481),
#  ('king', 7456),
#  ('law', 7435),
#  ('group', 7417),
#  ('film', 7400),
#  ('still', 7378),
#  ('until', 7368),
#  ('north', 7328),
#  ('international', 7262),
#  ('term', 7219),
#  ('we', 7118),
#  ('end', 7113),
#  ('book', 7110),
#  ('found', 7043),
#  ('own', 7034),
#  ('political', 6970),
#  ('party', 6943),
#  ('order', 6908),
#  ('usually', 6872),
#  ('president', 6865),
#  ('church', 6786),
#  ('you', 6690),
#  ('death', 6684),
#  ('theory', 6604),
#  ('area', 6591),
#  ('around', 6576),
#  ('include', 6531),
#  ('god', 6518),
#  ('ii', 6494),
#  ('way', 6433),
#  ('did', 6419),
#  ('military', 6410),
#  ('population', 6400),
#  ('using', 6384),
#  ('though', 6362),
#  ('small', 6361),
#  ('following', 6300),
#  ('within', 6238),
#  ('non', 6220),
#  ('human', 6184),
#  ('left', 6184),
#  ('main', 6166),
#  ('among', 6146),
#  ('point', 6141),
#  ('r', 6064),
#  ('due', 6056),
#  ('p', 6001),
#  ('considered', 5985),
#  ('public', 5976),
#  ('popular', 5967),
#  ('computer', 5874),
#  ('west', 5862),
#  ('family', 5857),
#  ('east', 5854),
#  ('information', 5844),
#  ('important', 5843),
#  ('european', 5806),
#  ('man', 5778),
#  ('sometimes', 5761),
#  ('right', 5758),
#  ('old', 5711),
#  ('free', 5684),
#  ('word', 5678),
#  ('without', 5661),
#  ('last', 5654),
#  ('us', 5652),
#  ('members', 5634),
#  ('given', 5605),
#  ('times', 5582),
#  ('roman', 5468),
#  ('make', 5450),
#  ('h', 5404),
#  ('age', 5350),
#  ('place', 5345),
#  ('l', 5343),
#  ('thus', 5319),
#  ('science', 5314),
#  ('case', 5289),
#  ('become', 5268),
#  ('systems', 5262),
#  ('union', 5248),
#  ('born', 5246),
#  ('york', 5243),
#  ('line', 5236),
#  ('countries', 5231),
#  ('does', 5221),
#  ('isbn', 5216),
#  ('st', 5207),
#  ('control', 5196),
#  ('various', 5163),
#  ('others', 5160),
#  ('house', 5157),
#  ('article', 5143),
#  ('island', 5124),
#  ('should', 5113),
#  ('led', 5108),
#  ('back', 5105),
#  ('period', 5099),
#  ('player', 5096),
#  ('europe', 5094),
#  ('languages', 5087),
#  ('central', 5070),
#  ('water', 5025),
#  ('few', 5013),
#  ('western', 5010),
#  ('home', 5007),
#  ('began', 5004),
#  ('generally', 4979),
#  ('less', 4974),
#  ('k', 4970),
#  ('similar', 4939),
#  ('written', 4916),
#  ('original', 4910),
#  ('best', 4902),
#  ('must', 4898),
#  ('according', 4884),
#  ('school', 4872),
#  ('france', 4813),
#  ('air', 4802),
#  ('single', 4801),
#  ('force', 4776),
#  ('v', 4762),
#  ('land', 4755),
#  ('groups', 4731),
#  ('down', 4728),
#  ('how', 4727),
#  ('works', 4724),
#  ('development', 4721),
#  ('official', 4720),
#  ('support', 4686),
#  ('england', 4641),
#  ('j', 4612),
#  ('rather', 4605),
#  ('data', 4586),
#  ('space', 4586),
#  ('greek', 4577),
#  ('km', 4574),
#  ('named', 4551),
#  ('germany', 4539),
#  ('just', 4528),
#  ('games', 4527),
#  ('said', 4483),
#  ('version', 4472),
#  ('late', 4471),
#  ('earth', 4457),
#  ('company', 4448),
#  ('every', 4446),
#  ('economic', 4435),
#  ('short', 4433),
#  ('published', 4430),
#  ('black', 4429),
#  ('army', 4418),
#  ('off', 4414),
#  ('london', 4399),
#  ('million', 4386),
#  ('body', 4383),
#  ('field', 4352),
#  ('christian', 4347),
#  ('either', 4330),
#  ('social', 4307),
#  ('empire', 4307),
#  ('o', 4299),
#  ('developed', 4270),
#  ('standard', 4269),
#  ('court', 4268),
#  ('service', 4260),
#  ('kingdom', 4257),
#  ('along', 4241),
#  ('college', 4236),
#  ('republic', 4231),
#  ('sea', 4212),
#  ('america', 4202),
#  ('today', 4198),
#  ('result', 4193),
#  ('held', 4178),
#  ('team', 4176),
#  ('light', 4172),
#  ('means', 4165),
#  ('never', 4127),
#  ('especially', 4125),
#  ('third', 4121),
#  ('further', 4118),
#  ('character', 4114),
#  ('forces', 4114),
#  ('take', 4105),
#  ('men', 4078),
#  ('society', 4067),
#  ('show', 4064),
#  ('open', 4063),
#  ('possible', 4051),
#  ('fact', 4042),
#  ('battle', 4034),
#  ('took', 4013),
#  ('former', 4007),
#  ('books', 3992),
#  ('soviet', 3985),
#  ('river', 3984),
#  ('children', 3978),
#  ('having', 3964),
#  ('good', 3962),
#  ('local', 3960),
#  ('current', 3955),
#  ('son', 3955),
#  ('process', 3949),
#  ('natural', 3947),
#  ('present', 3922),
#  ('himself', 3919),
#  ('islands', 3903),
#  ('total', 3891),
#  ('near', 3874),
#  ('white', 3866),
#  ('days', 3863),
#  ('person', 3855),
#  ('itself', 3843),
#  ('seen', 3831),
#  ('culture', 3809),
#  ('little', 3805),
#  ('above', 3782),
#  ('software', 3773),
#  ('largest', 3772),
#  ('words', 3771),
#  ('upon', 3768),
#  ('level', 3767),
#  ('father', 3762),
#  ('created', 3760),
#  ('side', 3760),
#  ('red', 3755),
#  ('references', 3747),
#  ('press', 3745),
#  ('full', 3734),
#  ('region', 3726),
#  ('almost', 3717),
#  ('image', 3714),
#  ('al', 3714),
#  ('famous', 3708),
#  ('play', 3702),
#  ('came', 3698),
#  ('role', 3691),
#  ('once', 3686),
#  ('certain', 3675),
#  ('league', 3663),
#  ('jewish', 3662),
#  ('james', 3653),
#  ('january', 3650),
#  ('site', 3639),
#  ('again', 3616),
#  ('numbers', 3611),
#  ('art', 3611),
#  ('member', 3601),
#  ('areas', 3599),
#  ('movement', 3595),
#  ('religious', 3588),
#  ('type', 3588),
#  ('march', 3583),
#  ('community', 3581),
#  ('story', 3573),
#  ('played', 3572),
#  ('production', 3570),
#  ('released', 3555),
#  ('center', 3548),
#  ('rights', 3546),
#  ('real', 3545),
#  ('related', 3536),
#  ('foreign', 3528),
#  ('low', 3524),
#  ('ancient', 3523),
#  ('terms', 3519),
#  ('view', 3519),
#  ('source', 3503),
#  ('act', 3502),
#  ('minister', 3493),
#  ('change', 3483),
#  ('energy', 3464),
#  ('produced', 3457),
#  ('research', 3452),
#  ('actor', 3451),
#  ('making', 3448),
#  ('civil', 3443),
#  ('december', 3443),
#  ('women', 3442),
#  ('special', 3441),
#  ('style', 3438),
#  ('william', 3437),
#  ('design', 3437),
#  ('japanese', 3437),
#  ('available', 3435),
#  ('chinese', 3430),
#  ('forms', 3429),
#  ('canada', 3428),
#  ('northern', 3423),
#  ('died', 3418),
#  ('class', 3412),
#  ('living', 3410),
#  ('next', 3406),
#  ('particular', 3404),
#  ('program', 3403),
#  ('council', 3401),
#  ('television', 3395),
#  ('head', 3376),
#  ('david', 3368),
#  ('china', 3365),
#  ('middle', 3363),
#  ('established', 3360),
#  ('hand', 3356),
#  ('bc', 3356),
#  ('far', 3352),
#  ('july', 3333),
#  ('function', 3330),
#  ('position', 3318),
#  ('y', 3311),
#  ('built', 3310),
#  ('george', 3307),
#  ('band', 3304),
#  ('together', 3303),
#  ('w', 3301),
#  ('latin', 3290),
#  ('thought', 3277),
#  ('eastern', 3276),
#  ('charles', 3268),
#  ('parts', 3266),
#  ('instead', 3259),
#  ('study', 3248),
#  ('might', 3242),
#  ('india', 3242),
#  ('code', 3240),
#  ('included', 3213),
#  ('meaning', 3213),
#  ('trade', 3207),
#  ('per', 3206),
#  ('june', 3195),
#  ('least', 3185),
#  ('half', 3176),
#  ('model', 3141),
#  ('economy', 3136),
#  ('prime', 3135),
#  ('traditional', 3133),
#  ('always', 3131),
#  ('capital', 3129),
#  ('range', 3125),
#  ('november', 3119),
#  ('emperor', 3119),
#  ('young', 3109),
#  ('anti', 3103),
#  ('final', 3102),
#  ('text', 3098),
#  ('players', 3088),
#  ('uk', 3079),
#  ('april', 3069),
#  ('run', 3063),
#  ('september', 3055),
#  ('addition', 3050),
#  ('radio', 3050),
#  ('live', 3046),
#  ('august', 3044),
#  ('taken', 3043),
#  ('note', 3043),
#  ('italian', 3037),
#  ('lost', 3035),
#  ('nature', 3027),
#  ('project', 3022),
#  ('technology', 3017),
#  ('spanish', 3011),
#  ('october', 3009),
#  ('recent', 3002),
#  ('rate', 3002),
#  ('won', 2989),
#  ('true', 2965),
#  ('value', 2964),
#  ('uses', 2963),
#  ('russian', 2961),
#  ('est', 2959),
#  ('wrote', 2935),
#  ('effect', 2933),
#  ('album', 2932),
#  ('southern', 2927),
#  ('africa', 2923),
#  ('whose', 2914),
#  ('top', 2913),
#  ('historical', 2899),
#  ('australia', 2895),
#  ('catholic', 2888),
#  ('particularly', 2882),
#  ('self', 2879),
#  ('structure', 2876),
#  ('record', 2863),
#  ('evidence', 2857),
#  ('rule', 2852),
#  ('themselves', 2852),
#  ('influence', 2845),
#  ('cases', 2843),
#  ('subject', 2830),
#  ('referred', 2829),
#  ('continued', 2822),
#  ('nations', 2821),
#  ('below', 2819),
#  ('rock', 2819),
#  ('japan', 2817),
#  ('com', 2810),
#  ('song', 2809),
#  ('throughout', 2806),
#  ('names', 2806),
#  ('female', 2797),
#  ('title', 2796),
#  ('therefore', 2795),
#  ('our', 2795),
#  ('office', 2785),
#  ('star', 2784),
#  ('paul', 2777),
#  ('too', 2775),
#  ('cities', 2773),
#  ('february', 2771),
#  ('independent', 2771),
#  ('author', 2769),
#  ('problem', 2767),
#  ('species', 2761),
#  ('education', 2759),
#  ('done', 2759),
#  ('philosophy', 2758),
#  ('come', 2755),
#  ('higher', 2753),
#  ('originally', 2752),
#  ('market', 2748),
#  ('town', 2746),
#  ('my', 2745),
#  ('season', 2741),
#  ('love', 2740),
#  ('strong', 2736),
#  ('israel', 2735),
#  ('irish', 2731),
#  ('writer', 2731),
#  ('films', 2727),
#  ('elements', 2723),
#  ('robert', 2722),
#  ('whether', 2719),
#  ('despite', 2716),
#  ('eventually', 2714),
#  ('here', 2709),
#  ('football', 2708),
#  ('action', 2699),
#  ('internet', 2697),
#  ('individual', 2693),
#  ('sound', 2693),
#  ('network', 2691),
#  ('described', 2685),
#  ('practice', 2681),
#  ('characters', 2674),
#  ('re', 2664),
#  ('royal', 2663),
#  ('la', 2660),
#  ('events', 2650),
#  ('formed', 2644),
#  ('commonly', 2638),
#  ('base', 2633),
#  ('received', 2632),
#  ('african', 2628),
#  ('problems', 2628),
#  ('food', 2623),
#  ('jews', 2620),
#  ('able', 2619),
#  ('male', 2615),
#  ('typically', 2595),
#  ('mass', 2595),
#  ('complex', 2593),
#  ('lower', 2583),
#  ('includes', 2576),
#  ('outside', 2574),
#  ('legal', 2562),
#  ('complete', 2561),
#  ('significant', 2554),
#  ('parliament', 2554),
#  ('actually', 2553),
#  ('business', 2542),
#  ('fiction', 2540),
#  ('physical', 2539),
#  ('followed', 2537),
#  ('deaths', 2530),
#  ('key', 2527),
#  ('leader', 2525),
#  ('widely', 2525),
#  ('page', 2520),
#  ('basic', 2519),
#  ('types', 2518),
#  ('henry', 2494),
#  ('elected', 2493),
#  ('beginning', 2493),
#  ('fire', 2489),
#  ('building', 2480),
#  ('independence', 2478),
#  ('went', 2475),
#  ('movie', 2471),
#  ('aircraft', 2471),
#  ('ever', 2470),
#  ('canadian', 2468),
#  ('material', 2464),
#  ('births', 2462),
#  ('video', 2461),
#  ('news', 2458),
#  ('future', 2457),
#  ('scientific', 2456),
#  ('simply', 2454),
#  ('go', 2451),
#  ('defined', 2449),
#  ('laws', 2444),
#  ('get', 2440),
#  ('close', 2439),
#  ('industry', 2434),
#  ('specific', 2432),
#  ('examples', 2431),
#  ('believe', 2404),
#  ('services', 2404),
#  ('idea', 2398),
#  ('method', 2397),
#  ('introduced', 2397),
#  ('points', 2396),
#  ('return', 2395),
#  ('cause', 2392),
#  ('indian', 2389),
#  ('britain', 2384),
#  ('features', 2380),
#  ('majority', 2379),
#  ('size', 2379),
#  ('post', 2376),
#  ('lead', 2375),
#  ('organization', 2374),
#  ('cannot', 2373),
#  ('designed', 2364),
#  ('ireland', 2362),
#  ('cross', 2361),
#  ('classical', 2359),
#  ('personal', 2357),
#  ('writing', 2356),
#  ('concept', 2353),
#  ('associated', 2349),
#  ('required', 2349),
#  ('soon', 2343),
#  ('changes', 2337),
#  ('california', 2336),
#  ('located', 2336),
#  ('sense', 2331),
#  ('believed', 2319),
#  ('away', 2313),
#  ('started', 2313),
#  ('co', 2308),
#  ('religion', 2304),
#  ('mother', 2303),
#  ('county', 2300),
#  ('rules', 2299),
#  ('studies', 2298),
#  ('yet', 2296),
#  ('find', 2290),
#  ('knowledge', 2289),
#  ('put', 2288),
#  ('founded', 2282),
#  ('policy', 2278),
#  ('currently', 2275),
#  ('provide', 2272),
#  ('working', 2271),
#  ('media', 2267),
#  ('election', 2266),
#  ('australian', 2260),
#  ('me', 2256),
#  ('thomas', 2255),
#  ('allowed', 2252),
#  ('russia', 2251),
#  ('earlier', 2249),
#  ('greater', 2249),
#  ('limited', 2248),
#  ('object', 2243),
#  ('brought', 2241),
#  ('online', 2236),
#  ('association', 2231),
#  ('lord', 2231),
#  ('mostly', 2227),
#  ('blue', 2223),
#  ('constitution', 2222),
#  ('across', 2222),
#  ('added', 2218),
#  ('interest', 2217),
#  ('things', 2216),
#  ('relations', 2215),
#  ('speed', 2206),
#  ('federal', 2200),
#  ('singer', 2195),
#  ('effects', 2194),
#  ('growth', 2193),
#  ('sources', 2192),
#  ('your', 2189),
#  ('remains', 2183),
#  ('z', 2182),
#  ('probably', 2178),
#  ('gave', 2178),
#  ('simple', 2177),
#  ('attack', 2175),
#  ('longer', 2174),
#  ('reference', 2171),
#  ('saint', 2168),
#  ('success', 2164),
#  ('killed', 2163),
#  ('past', 2162),
#  ('career', 2162),
#  ('need', 2159),
#  ('park', 2156),
#  ('definition', 2147),
#  ('say', 2139),
#  ('etc', 2137),
#  ('give', 2133),
#  ('peace', 2133),
#  ('chief', 2130),
#  ('stories', 2128),
#  ('security', 2126),
#  ('wide', 2125),
#  ('ball', 2124),
#  ('saw', 2119),
#  ('machine', 2117),
#  ('better', 2116),
#  ('cell', 2115),
#  ('leading', 2114),
#  ('becomes', 2111),
#  ('spain', 2109),
#  ('larger', 2109),
#  ('products', 2108),
#  ('parties', 2108),
#  ('night', 2108),
#  ('remained', 2105),
#  ('prize', 2103),
#  ('months', 2102),
#  ('website', 2102),
#  ('big', 2102),
#  ('cultural', 2101),
#  ('money', 2101),
#  ('help', 2099),
#  ('territory', 2099),
#  ('private', 2098),
#  ('moved', 2098),
#  ('letter', 2093),
#  ('wife', 2093),
#  ('politics', 2090),
#  ('lines', 2090),
#  ('largely', 2089),
#  ('contains', 2086),
#  ('companies', 2084),
#  ('lake', 2080),
#  ('perhaps', 2079),
#  ('green', 2074),
#  ('already', 2070),
#  ('dead', 2069),
#  ('iii', 2069),
#  ('library', 2068),
#  ('separate', 2067),
#  ('refer', 2066),
#  ('makes', 2065),
#  ('appeared', 2064),
#  ('dutch', 2060),
#  ('holy', 2059),
#  ('era', 2057),
#  ('novel', 2054),
#  ('successful', 2052),
#  ('italy', 2050),
#  ('letters', 2049),
#  ('results', 2048),
#  ('matter', 2045),
#  ('produce', 2042),
#  ('origin', 2041),
#  ('claim', 2039),
#  ('whole', 2034),
#  ('directly', 2033),
#  ('attempt', 2033),
#  ('actress', 2031),
#  ('surface', 2030),
#  ('revolution', 2029),
#  ('highly', 2026),
#  ('caused', 2025),
#  ('status', 2024),
#  ('musical', 2022),
#  ('richard', 2021),
#  ('commercial', 2020),
#  ('division', 2018),
#  ('color', 2017),
#  ('health', 2013),
#  ('coast', 2013),
#  ('release', 2013),
#  ('latter', 2012),
#  ('authority', 2009),
#  ('treaty', 2007),
#  ('turn', 2005),
#  ('michael', 2000),
#  ('nation', 1995),
#  ('direct', 1994),
#  ('asia', 1992),
#  ('edition', 1990),
#  ('programming', 1989),
#  ('playing', 1981),
#  ('date', 1980),
#  ('mary', 1977),
#  ('native', 1977),
#  ('whom', 1977),
#  ('married', 1973),
#  ('towards', 1971),
#  ('issues', 1967),
#  ('double', 1966),
#  ('primary', 1959),
#  ('basis', 1959),
#  ('allow', 1958),
#  ('enough', 1958),
#  ('memory', 1957),
#  ('reason', 1954),
#  ('web', 1952),
#  ('exist', 1950),
#  ('provided', 1948),
#  ('oil', 1945),
#  ('course', 1945),
#  ('functions', 1945),
#  ('alexander', 1944),
#  ('analysis', 1944),
#  ('chemical', 1944),
#  ('mid', 1941),
#  ('replaced', 1941),
#  ('queen', 1940),
#  ('claims', 1938),
#  ('tv', 1938),
#  ('sun', 1938),
#  ('literature', 1936),
#  ('metal', 1935),
#  ('amount', 1934),
#  ('divided', 1930),
#  ('blood', 1927),
#  ('likely', 1926),
#  ('access', 1924),
#  ('average', 1924),
#  ('length', 1922),
#  ('smaller', 1921),
#  ('medical', 1919),
#  ('property', 1918),
#  ('students', 1916),
#  ('degree', 1915),
#  ('elections', 1914),
#  ('club', 1913),
#  ('claimed', 1912),
#  ('performance', 1911),
#  ('director', 1907),
#  ('digital', 1905),
#  ('front', 1904),
#  ('museum', 1904),
#  ('difficult', 1903),
#  ('tradition', 1903),
#  ('nearly', 1902),
#  ('schools', 1900),
#  ('washington', 1899),
#  ('gas', 1897),
#  ('jesus', 1896),
#  ('map', 1896),
#  ('louis', 1895),
#  ('rome', 1895),
#  ('unit', 1892),
#  ('baseball', 1890),
#  ('mind', 1888),
#  ('peter', 1887),
#  ('mark', 1887),
#  ('collection', 1883),
#  ('product', 1881),
#  ('congress', 1880),
#  ('programs', 1872),
#  ('changed', 1871),
#  ('ideas', 1870),
#  ('moon', 1868),
#  ('entire', 1866),
#  ('user', 1865),
#  ('ground', 1864),
#  ('records', 1862),
#  ('frequently', 1861),
#  ('increase', 1860),
#  ('highest', 1859),
#  ('sent', 1858),
#  ('finally', 1858),
#  ('board', 1857),
#  ('don', 1856),
#  ('notable', 1854),
#  ('read', 1852),
#  ('methods', 1852),
#  ('recently', 1851),
#  ('bit', 1849),
#  ('involved', 1843),
#  ('variety', 1843),
#  ('call', 1842),
#  ('democratic', 1841),
#  ('ten', 1840),
#  ('served', 1836),
#  ('minor', 1830),
#  ('hard', 1828),
#  ('birth', 1823),
#  ('objects', 1823),
#  ('nuclear', 1819),
#  ('increased', 1819),
#  ('section', 1813),
#  ('street', 1812),
#  ('windows', 1811),
#  ('relatively', 1810),
#  ('car', 1809),
#  ('move', 1808),
#  ('create', 1807),
#  ('returned', 1807),
#  ('bank', 1806),
#  ('conditions', 1805),
#  ('operation', 1802),
#  ('adopted', 1801),
#  ('relationship', 1801),
#  ('christ', 1800),
#  ('hall', 1797),
#  ('appear', 1794),
#  ('rest', 1790),
#  ('child', 1789),
#  ('element', 1787),
#  ('appears', 1786),
#  ('takes', 1783),
#  ...]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'term', 'anarchism', 'originated', 'originated', 'of', 'term', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable( tf.truncated_normal([vocabulary_size, embedding_size], stddev = 1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph = graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.067591
# Nearest to over: qquad, depths, coastlines, booksellers, throat, halley, gorman, commercial,
# Nearest to s: hairdresser, shiny, wealth, kittyhawk, trafford, maharaja, mumia, accomplices,
# Nearest to these: pashtun, tumble, inflammation, hui, lalr, cancellation, materially, ricardian,
# Nearest to can: coupon, shel, reliance, northside, zapatista, qumran, amaranth, launching,
# Nearest to would: ammonite, pang, transnistrian, windowing, dualism, spokesman, fraunhofer, islam,
# Nearest to called: liner, distances, alyattes, benetton, lovelace, gamblers, druid, sparing,
# Nearest to i: fingal, dominic, independent, conflicted, chickenpox, storage, varies, vivid,
# Nearest to no: ambiguous, light, materialist, mississippi, trip, detainee, folklore, preachers,
# Nearest to often: bouvines, bormann, mandibles, losing, boucher, alternating, ii, paced,
# Nearest to there: utility, gui, tackle, mvd, parcel, bradshaw, getz, junkie,
# Nearest to if: lamented, senado, levels, amazing, biblical, ploughing, administratively, maidstone,
# Nearest to th: promulgate, bombs, refectory, babylonians, prosecuted, lictors, conscript, fearsome,
# Nearest to history: examining, niagara, mifune, maiden, rostock, devotions, retract, peloponnesian,
# Nearest to or: misalignment, outfielder, carthusian, quarto, baker, treaty, evolutionist, deuterocanonical,
# Nearest to however: salamanca, breasts, workgroup, filed, grander, upbringing, mentality, mariana,
# Nearest to that: goldoni, affiliation, diluted, diena, wieman, exiting, volk, balloon,
# Average loss at step 2000: 4.368458
# Average loss at step 4000: 3.867042
# Average loss at step 6000: 3.784408
# Average loss at step 8000: 3.683347
# Average loss at step 10000: 3.619153
# Nearest to over: qquad, maximilien, commercial, fetus, stem, coastlines, communions, control,
# Nearest to s: his, iga, and, swollen, arranger, acquaintance, wichita, irresponsibility,
# Nearest to these: tumble, mark, materially, composed, cancellation, harshly, enchantment, wherever,
# Nearest to can: would, may, must, infrequently, might, will, paparazzi, could,
# Nearest to would: can, could, will, bubbles, to, gotham, must, crucially,
# Nearest to called: sometimes, distances, notable, liner, benetton, gamblers, lovelace, criterion,
# Nearest to i: storage, conflicted, fingal, leo, hummers, consistory, unfortunately, independent,
# Nearest to no: resistor, scorned, they, seals, detainee, valdivia, it, light,
# Nearest to often: it, bormann, also, commonly, sometimes, suspicious, anconia, that,
# Nearest to there: it, they, also, abrupt, he, customization, bradshaw, highly,
# Nearest to if: where, finches, gebhard, centric, normandy, marmara, rameau, ploughing,
# Nearest to th: three, four, five, seven, six, conscious, fearsome, graceful,
# Nearest to history: examining, list, mifune, chalice, nuncio, fingernails, searchers, leapt,
# Nearest to or: and, deporting, vers, overview, betrothal, than, peacocks, cursus,
# Nearest to however: conquers, breasts, filed, upbringing, eiji, combo, through, lower,
# Nearest to that: which, diluted, therefore, it, marshallese, lamenting, ama, this,
# Average loss at step 12000: 3.602884
# Average loss at step 14000: 3.570341
# Average loss at step 16000: 3.411240
# Average loss at step 18000: 3.460455
# Average loss at step 20000: 3.541651
# Nearest to over: uniformitarianism, reflux, qquad, admire, carrie, compelled, collimated, honorary,
# Nearest to s: swollen, yale, educational, mondegreens, faerie, displays, surrogate, anders,
# Nearest to these: many, some, all, other, enchantment, lcd, composed, others,
# Nearest to can: may, would, must, could, will, might, infrequently, should,
# Nearest to would: can, will, could, may, must, should, might, to,
# Nearest to called: notable, benetton, sometimes, distances, liner, wrappings, gamblers, bodhi,
# Nearest to i: storage, ii, we, conflicted, fantasyland, wabash, drucker, leo,
# Nearest to no: resistor, a, seals, dorothea, there, scorned, anthropology, wax,
# Nearest to often: commonly, sometimes, also, generally, suspicious, clearly, that, bormann,
# Nearest to there: it, they, he, which, abrupt, also, mentioned, no,
# Nearest to if: where, centric, when, marmara, amr, but, normandy, gebhard,
# Nearest to th: three, conscious, fearsome, eight, wrinkled, graceful, codon, weasel,
# Nearest to history: examining, list, mifune, leapt, raccoon, nuncio, chalice, fingernails,
# Nearest to or: than, and, deporting, for, mathematik, consensual, cyril, with,
# Nearest to however: but, combo, that, conquers, karts, eiji, possess, and,
# Nearest to that: which, but, exiting, however, this, actors, essene, genuine,
# Average loss at step 22000: 3.494305
# Average loss at step 24000: 3.491486
# Average loss at step 26000: 3.484847
# Average loss at step 28000: 3.481518
# Average loss at step 30000: 3.499612
# Nearest to over: uniformitarianism, admire, reflux, centre, collimated, carrie, compelled, borer,
# Nearest to s: his, excretion, whose, sven, binghamton, its, kittyhawk, ambulance,
# Nearest to these: some, many, several, such, those, all, they, are,
# Nearest to can: would, may, could, will, must, might, should, cannot,
# Nearest to would: can, could, will, may, must, should, might, to,
# Nearest to called: notable, benetton, monistic, sometimes, liner, distances, cinemas, net,
# Nearest to i: ii, storage, we, aardwolf, wabash, drucker, conflicted, you,
# Nearest to no: dorothea, resistor, there, pacing, churchman, nothing, mmorpgs, valdivia,
# Nearest to often: sometimes, commonly, generally, also, still, clearly, now, suspicious,
# Nearest to there: they, it, he, not, this, anaesthesia, who, often,
# Nearest to if: when, where, though, normandy, centric, amr, although, marmara,
# Nearest to th: six, eight, two, fearsome, graceful, nd, wronged, four,
# Nearest to history: list, examining, raccoon, leapt, mifune, ganglion, form, searchers,
# Nearest to or: and, ventures, draped, but, peripatetic, than, cyril, without,
# Nearest to however: but, although, combo, though, and, when, that, karts,
# Nearest to that: which, but, this, however, exiting, diluted, what, goldoni,
# Average loss at step 32000: 3.505360
# Average loss at step 34000: 3.488648
# Average loss at step 36000: 3.456325
# Average loss at step 38000: 3.301435
# Average loss at step 40000: 3.429257
# Nearest to over: across, uniformitarianism, right, maximilien, admire, heartbeat, borer, carrie,
# Nearest to s: romanticized, hellene, whose, his, pianists, recognising, serialism, contraceptive,
# Nearest to these: some, many, several, such, those, all, both, they,
# Nearest to can: would, may, could, will, must, might, should, cannot,
# Nearest to would: could, will, can, may, must, should, might, cannot,
# Nearest to called: notable, benetton, cinemas, monistic, lombardo, sunk, sometimes, kilmer,
# Nearest to i: we, you, ii, storage, t, drucker, they, he,
# Nearest to no: any, dorothea, resistor, churchman, unfaithful, pacing, scorned, there,
# Nearest to often: sometimes, also, commonly, still, generally, usually, now, which,
# Nearest to there: they, it, he, which, often, still, now, she,
# Nearest to if: when, where, though, humane, for, electorates, centric, hindemith,
# Nearest to th: six, eight, graceful, fearsome, nine, five, zero, nd,
# Nearest to history: list, leapt, coffers, book, searchers, baikal, raccoon, ganglion,
# Nearest to or: and, than, ventures, a, hamlets, vegetarianism, but, deporting,
# Nearest to however: but, although, though, that, combo, casanova, zone, it,
# Nearest to that: which, this, therefore, however, what, it, who, repackaged,
# Average loss at step 42000: 3.437595
# Average loss at step 44000: 3.456877
# Average loss at step 46000: 3.450883
# Average loss at step 48000: 3.352552
# Average loss at step 50000: 3.381697
# Nearest to over: across, through, right, reflux, admire, vicu, borer, extended,
# Nearest to s: technik, faerie, whose, his, courtship, and, serialism, hellene,
# Nearest to these: some, many, several, such, those, both, certain, all,
# Nearest to can: could, may, will, would, must, might, should, cannot,
# Nearest to would: will, could, can, may, must, might, should, does,
# Nearest to called: notable, cinemas, aggressively, known, named, lombardo, homestead, emir,
# Nearest to i: we, you, ii, storage, they, consistory, drucker, aardwolf,
# Nearest to no: any, dorothea, churchman, blacki, pani, periodicals, mouthwash, conditioned,
# Nearest to often: sometimes, generally, commonly, still, usually, also, now, frequently,
# Nearest to there: they, it, he, she, still, believed, now, which,
# Nearest to if: when, where, though, humane, centric, before, because, so,
# Nearest to th: graceful, six, three, chroniclers, eight, bc, fearsome, ad,
# Nearest to history: list, leapt, baikal, ganglion, weathering, translations, raccoon, book,
# Nearest to or: and, than, like, though, ventures, cyril, iris, noboa,
# Nearest to however: but, although, though, that, while, when, where, identifiers,
# Nearest to that: which, however, but, where, microcebus, genuine, shermer, although,
# Average loss at step 52000: 3.435692
# Average loss at step 54000: 3.426555
# Average loss at step 56000: 3.437338
# Average loss at step 58000: 3.395684
# Average loss at step 60000: 3.395126
# Nearest to over: across, through, between, reflux, uniformitarianism, into, admire, extended,
# Nearest to s: stillness, edits, whose, gos, dino, menlo, understands, holiness,
# Nearest to these: many, some, those, several, both, all, such, which,
# Nearest to can: may, could, would, will, must, might, cannot, should,
# Nearest to would: will, could, can, may, must, might, should, did,
# Nearest to called: notable, used, known, aggressively, mentions, emir, carney, homestead,
# Nearest to i: we, you, ii, storage, god, aardwolf, drucker, consistory,
# Nearest to no: any, churchman, dorothea, little, only, blacki, aquatic, circumflex,
# Nearest to often: sometimes, usually, commonly, generally, still, also, now, frequently,
# Nearest to there: it, they, he, she, still, now, we, this,
# Nearest to if: when, where, though, because, humane, before, cannot, pacheco,
# Nearest to th: six, five, eight, four, graceful, nd, ad, fearsome,
# Nearest to history: leapt, list, politics, development, vil, antioxidant, carnivorous, raccoon,
# Nearest to or: and, than, cfo, correlations, allston, expiring, lighthouses, but,
# Nearest to however: but, although, though, that, when, while, adp, and,
# Nearest to that: which, however, this, it, what, there, but, truncation,
# Average loss at step 62000: 3.240356
# Average loss at step 64000: 3.249483
# Average loss at step 66000: 3.407584
# Average loss at step 68000: 3.394555
# Average loss at step 70000: 3.356091
# Nearest to over: across, uniformitarianism, meritocracy, reflux, about, around, admire, borer,
# Nearest to s: whose, technik, isbn, must, stillness, eusebio, ron, sven,
# Nearest to these: many, such, some, those, several, are, both, the,
# Nearest to can: may, could, will, would, must, might, cannot, should,
# Nearest to would: will, could, can, may, might, must, should, cannot,
# Nearest to called: mentions, named, known, used, aggressively, paleo, considered, carney,
# Nearest to i: we, you, ii, g, storage, drucker, aardwolf, bayou,
# Nearest to no: any, little, blacki, dorothea, churchman, aquatic, there, standings,
# Nearest to often: sometimes, usually, commonly, generally, frequently, still, now, also,
# Nearest to there: they, it, he, we, still, she, this, generally,
# Nearest to if: when, though, where, humane, because, although, before, while,
# Nearest to th: bc, graceful, ad, nd, fearsome, eight, seven, five,
# Nearest to history: list, leapt, translations, bcs, vil, weathering, carnivorous, politics,
# Nearest to or: and, than, the, like, while, occam, any, telophase,
# Nearest to however: but, although, though, that, while, when, where, if,
# Nearest to that: which, however, but, this, what, therefore, truncation, generally,
# Average loss at step 72000: 3.375947
# Average loss at step 74000: 3.350052
# Average loss at step 76000: 3.320583
# Average loss at step 78000: 3.358062
# Average loss at step 80000: 3.380284
# Nearest to over: across, around, reflux, between, through, borer, uniformitarianism, woodlands,
# Nearest to s: technik, chronicon, lederman, whose, maneuverability, his, holiness, stillness,
# Nearest to these: many, several, those, both, such, some, various, stoic,
# Nearest to can: could, will, may, would, must, cannot, might, should,
# Nearest to would: will, could, can, may, might, must, should, does,
# Nearest to called: used, known, named, considered, termed, aggressively, word, artery,
# Nearest to i: ii, you, we, g, drucker, aardwolf, achaeans, lossy,
# Nearest to no: little, any, blacki, dorothea, churchman, nudity, errol, relic,
# Nearest to often: sometimes, usually, commonly, generally, still, frequently, also, typically,
# Nearest to there: it, they, he, she, still, we, generally, usually,
# Nearest to if: when, though, where, before, because, humane, cannot, since,
# Nearest to th: five, bc, graceful, ad, fearsome, nd, four, three,
# Nearest to history: list, bcs, translations, bromley, development, gantry, introduction, triassic,
# Nearest to or: and, than, while, unselfish, cfo, mcclory, middletown, dactylic,
# Nearest to however: although, but, though, that, while, where, when, casablanca,
# Nearest to that: which, however, what, genuine, where, exiting, thus, abergavenny,
# Average loss at step 82000: 3.405789
# Average loss at step 84000: 3.412799
# Average loss at step 86000: 3.390618
# Average loss at step 88000: 3.351330
# Average loss at step 90000: 3.366798
# Nearest to over: across, around, through, reflux, uniformitarianism, about, concerning, knowing,
# Nearest to s: whose, isbn, stillness, technik, his, arranger, faerie, labelling,
# Nearest to these: several, many, some, those, are, all, both, such,
# Nearest to can: could, may, will, would, must, might, cannot, should,
# Nearest to would: could, will, can, might, may, must, should, did,
# Nearest to called: named, termed, used, considered, known, artery, referred, apologize,
# Nearest to i: ii, you, we, g, drucker, lossy, iii, aardwolf,
# Nearest to no: little, any, only, dorothea, relic, another, ambiguous, inorganic,
# Nearest to often: sometimes, commonly, usually, generally, frequently, still, also, now,
# Nearest to there: it, they, he, still, she, we, now, actually,
# Nearest to if: when, where, though, because, before, humane, although, so,
# Nearest to th: seven, nine, graceful, ad, bc, st, nd, six,
# Nearest to history: list, translations, gantry, bcs, triassic, baikal, politics, society,
# Nearest to or: and, including, uncharacteristic, but, than, though, middletown, correlations,
# Nearest to however: although, but, though, that, while, where, xaver, since,
# Nearest to that: which, however, what, but, goldoni, mcneil, who, shermer,
# Average loss at step 92000: 3.401777
# Average loss at step 94000: 3.257738
# Average loss at step 96000: 3.359611
# Average loss at step 98000: 3.243323
# Average loss at step 100000: 3.357521
# Nearest to over: across, through, uniformitarianism, between, around, admire, knowing, concerning,
# Nearest to s: whose, his, binghamton, joliet, technik, recognising, isbn, domitius,
# Nearest to these: several, some, many, those, both, such, were, all,
# Nearest to can: may, could, must, will, would, cannot, should, might,
# Nearest to would: could, will, can, may, might, must, should, cannot,
# Nearest to called: named, termed, used, UNK, known, homestead, referred, mandaeanism,
# Nearest to i: you, we, ii, they, jewellery, iii, t, lossy,
# Nearest to no: any, little, there, valdivia, churchman, blacki, another, periodicals,
# Nearest to often: sometimes, usually, commonly, generally, frequently, still, typically, now,
# Nearest to there: they, he, it, still, we, generally, often, she,
# Nearest to if: when, where, though, because, before, while, although, pacheco,
# Nearest to th: nd, bc, graceful, rd, six, ad, st, fearsome,
# Nearest to history: list, gantry, bcs, translations, baikal, icon, society, bromley,
# Nearest to or: and, than, iris, expiring, cfo, but, per, levellers,
# Nearest to however: but, although, though, that, where, while, and, especially,
# Nearest to that: which, however, what, this, but, essene, who, domed,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %%
len(data)
# Out:
# 17005207

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
